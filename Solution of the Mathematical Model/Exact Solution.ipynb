# %%
import pulp

# Parameters (example values, replace with actual data)
n = 5  # Number of potential tour packages
m = 4  # Number of seasons
c_i = [10, 20, 15, 25, 30]  # Cost of designing and operating each package
c_k = [5, 10]  # Cost per unit of resource
p_i = [50, 60, 70, 80, 90]  # Price of each package
b_r = 1000  # Maximum budget for resources
R_k = [200, 300]  # Available amount of each resource
r_ijk = [[[5, 2], [3, 1], [4, 2], [2, 1]],  # Resource allocation for each package in each season
         [[6, 3], [4, 2], [5, 3], [3, 2]],
         [[7, 4], [5, 3], [6, 4], [4, 3]],
         [[8, 5], [6, 4], [7, 5], [5, 4]],
         [[9, 6], [7, 5], [8, 6], [6, 5]]]
d_min = [20, 30, 25, 35, 40]  # Minimum desired demand for each package
d_max = [50, 60, 55, 65, 70]  # Maximum desired demand for each package
d_ij = [[30, 40, 35, 45],  # Demand for each package in each season
        [40, 50, 45, 55],
        [35, 45, 40, 50],
        [45, 55, 50, 60],
        [50, 60, 55, 65]]
m_ij = [2, 3, 3, 2, 2]  # Maximum number of packages to offer per season

# Decision Variables
x = pulp.LpVariable.dicts("x", ((i, j) for i in range(n) for j in range(m)), cat='Binary')

# Objective Function
objective = pulp.lpSum(p_i[i] * d_ij[i][j] * x[i, j] for i in range(n) for j in range(m)) - \
            pulp.lpSum(c_i[i] * x[i, j] for i in range(n) for j in range(m)) - \
            pulp.lpSum(c_k[k] * r_ijk[i][j][k] * x[i, j] for i in range(n) for j in range(m) for k in range(len(c_k)))

# Create the problem
prob = pulp.LpProblem("TourPackageOptimization", pulp.LpMaximize)
prob += objective

# Constraints

# Budget Constraints
for i in range(n):
    for j in range(m):
        prob += pulp.lpSum(c_k[k] * r_ijk[i][j][k] * x[i, j] for k in range(len(c_k))) <= b_r

# Resource Constraints
for k in range(len(c_k)):
    for j in range(m):
        prob += pulp.lpSum(r_ijk[i][j][k] * x[i, j] for i in range(n)) <= R_k[k]

# Demand Constraints
for i in range(n):
    for j in range(m):
        prob += d_ij[i][j] * x[i, j] >= d_min[i]
        prob += d_ij[i][j] * x[i, j] <= d_max[i]

# Package Offering Constraints
for j in range(m):
    prob += pulp.lpSum(x[i, j] for i in range(n)) <= m_ij[j]

# Solve the problem
prob.solve()

# Print the results
for i in range(n):
    for j in range(m):
        print(f"Package {i} in season {j} ")

print(f"Objective value:$ {int(pulp.value(prob.objective))}")
# Out:
# Package 0 in season 0
# Package 0 in season 1
# Package 0 in season 2
# Package 0 in season 3
# Package 1 in season 0
# Package 1 in season 1
# Package 1 in season 2
# Package 1 in season 3
# Package 2 in season 0
# Package 2 in season 1
# Package 2 in season 2
# Package 2 in season 3
# Package 3 in season 0
# Package 3 in season 1
# Package 3 in season 2
# Package 3 in season 3
# Package 4 in season 0
# Package 4 in season 1
# Package 4 in season 2
# Package 4 in season 3
# Objective value:$ 35593

# %%
import pulp
import pandas as pd
import locale

# Set locale for currency formatting
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')

# Load the Excel file
file_path = 'C:/Users/Mohammed/OneDrive/Desktop/use data.xlsx'
data = pd.read_excel(file_path, sheet_name='Data')

# Extract unique tour packages and seasons
tour_packages = data['Tour Name'].unique()
seasons = data['Season'].unique()

# Create integer indices for tour packages and seasons
tour_package_indices = {tour: idx for idx, tour in enumerate(tour_packages)}
season_indices = {season: idx for idx, season in enumerate(seasons)}

# Number of tour packages and seasons
n = len(tour_packages)
m = len(seasons)

# Parameters
c_i = data['Cost of Package Per Tourist'].tolist()
c_k = data['Cost per unit of resources'].unique().tolist()
p_i = data['Price'].tolist()
b_r = 1000000  # Maximum budget for resources
R_k = data['#Available Resources'].unique().tolist()
d_min = data['Minimum Demand'].tolist()
d_max = data['Maximum Demand'].tolist()

# Create a pivot table for actual demand
demand_pivot = data.pivot(index='Tour Name', columns='Season', values='Actual Demand')
d_ij = demand_pivot.fillna(0).values.tolist()  # Fill NA values with 0 for missing data

# Initialize r_ijk as a 3-dimensional list
r_ijk = [[[0 for _ in range(len(c_k))] for _ in range(m)] for _ in range(n)]

# Fill r_ijk with values from the dataframe
for row in data.itertuples():
    i = tour_package_indices[row._1]
    j = season_indices[row.Season]
    for k in range(len(c_k)):
        r_ijk[i][j][k] = row._8  # Adjust this index if necessary based on the dataframe structure

m_ij = [50] * m  # Maximum number of packages to offer per season

# Decision Variables
x = pulp.LpVariable.dicts("x", ((i, j) for i in range(n) for j in range(m)), cat='Binary')

# Objective Function
objective = pulp.lpSum(p_i[i] * d_ij[i][j] * x[i, j] for i in range(n) for j in range(m)) - \
            pulp.lpSum(c_i[i] * d_ij[i][j] * x[i, j] for i in range(n) for j in range(m)) - \
            pulp.lpSum(c_k[k] * r_ijk[i][j][k] * x[i, j] for i in range(n) for j in range(m) for k in range(len(c_k)))

# Create the problem
prob = pulp.LpProblem("TourPackageOptimization", pulp.LpMaximize)
prob += objective

# Constraints

# Budget Constraints
for i in range(n):
    for j in range(m):
        prob += pulp.lpSum(c_k[k] * r_ijk[i][j][k] * x[i, j] for k in range(len(c_k))) <= b_r

# Resource Constraints
for k in range(len(c_k)):
    for j in range(m):
        prob += pulp.lpSum(r_ijk[i][j][k] * x[i, j] for i in range(n)) <= R_k[k]

# Demand Constraints
for i in range(n):
    for j in range(m):
        prob += d_ij[i][j] * x[i, j] >= d_min[i]
        prob += d_ij[i][j] * x[i, j] <= d_max[i]

# Package Offering Constraints
for j in range(m):
    prob += pulp.lpSum(x[i, j] for i in range(n)) <= m_ij[j]

# Prevent offering packages in non-existent seasons
for i in range(n):
    for j in range(m):
        if demand_pivot.at[tour_packages[i], seasons[j]] == 0:
            prob += x[i, j] == 0

# Solve the problem
prob.solve()

# Calculate revenue, cost, and profit
total_revenue = 0
total_cost = 0
total_package_cost = 0
total_resource_cost = 0

for i in range(n):
    for j in range(m):
        if pulp.value(x[i, j]) == 1:
            total_revenue += p_i[i] * d_ij[i][j]
            total_package_cost += c_i[i] * d_ij[i][j]
            total_resource_cost += sum(c_k[k] * r_ijk[i][j][k] * d_ij[i][j] for k in range(len(c_k)))

total_cost = total_package_cost + total_resource_cost
profit = total_revenue - total_cost

# Print the results for packages that are offered (x[i, j] == 1)
offered_packages = []
for i in range(n):
    for j in range(m):
        if pulp.value(x[i, j]) == 1:
            offered_packages.append((tour_packages[i], seasons[j]))

# Print the offered packages
for package, season in offered_packages:
    print('---------------------------------------------------')
    print()
    print(f"Package: {package} --> in season: {season} --> is offered.")

# Print the number of packages offered
num_offered_packages = len(offered_packages)
print()
print('---------------------------------------------------')
print(f"Number of packages offered: {num_offered_packages}")
print('---------------------------------------------------')

# Print the objective value as currency
objective_value = int(pulp.value(prob.objective))
print(f"Objective value: {(locale.currency(objective_value, grouping=True))}")
# Out:
# ---------------------------------------------------
#
# Package: 5 Days Nile Cruise from Sharm El Sheikh --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Alexandria, Cairo and Nile Cruise Holidays --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Alexandria, Cairo and Nile Cruise Holidays --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Egypt Adventure Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Egypt Adventure Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Egypt Adventure Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt & Jordan Tour to Cairo, Nile Cruise & Petra Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt & Jordan Tour to Cairo, Nile Cruise & Petra Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Budget Tour to Cairo, Nile Cruise & Alexandria --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Egypt Cheap Tour to Cairo, Nile Cruise & Alexandria --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Egypt Cheap Tour to Cairo, Nile Cruise & Alexandria --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Culture Trip to Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Culture Trip to Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Culture Trip to Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Cairo and Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Recreational Trip to Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Recreational Trip to Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt in 9 Days --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Classical Tour In Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt Cultural Sightseeing in 10 Days --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt Cultural Sightseeing in 10 Days --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Pyramids & Nile Cruise Holidays by Air --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Historical Vacation in Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Historical Vacation in Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 6 Days Egypt Jewels Luxury Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Taste of Egypt in 9 Days Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Treasures of Egypt in 11 Days Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Treasures of Egypt in 11 Days Luxury Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Explore Egypt in 12 Days Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Explore Egypt in 12 Days Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Discover Ancient Egypt in 8 Days Luxury Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Discover Ancient Egypt in 8 Days Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Ultimate Egypt in 8 Days Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Egypt Jewels 10 Days Luxury Holiday With Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Easter Cairo & Ancient Egypt Nile River Cruise --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Easter Cairo & Ancient Egypt Nile River Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Easter Cairo & Ancient Egypt Nile River Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Honeymoon Cairo & Nile Adventure Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt in 10 Days Honeymoon Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt Classic and Romantic Honeymoon Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt Classic and Romantic Honeymoon Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Honeymoon Historical Holiday in Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Essential Egypt Honeymoon Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Essential Egypt Honeymoon Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Lovely Honeymoon Tour Package Across Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Lovely Honeymoon Tour Package Across Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt in Luxury with Sanctuary Sun Boat III Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo & Upper Egypt Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Overland Trip Package in Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Overland Trip Package in Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Trip to the Best of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Trip to the Best of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Exceptional Trip Package in Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Luxury Cairo and Dahabiya Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Luxury Cairo and Dahabiya Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Luxury Cairo and Dahabiya Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Magnificent Egypt Tour for Senior Include Abu Simbel --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Magnificent Egypt Tour for Senior Include Abu Simbel --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Magnificent Egypt Tour for Senior Include Abu Simbel --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Golden Egypt Tour for Solo Women --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Solo Woman Tour to Essential Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Solo Woman Tour to Essential Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Solo Woman Tour to Essential Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Cleopatra’s Cairo & Nile Cruise Tour for Solo Woman --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Cleopatra’s Cairo & Nile Cruise Tour for Solo Woman --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Solo Woman Trip To Cairo, Hurghada, and Upper Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Solo Woman Trip To Cairo, Hurghada, and Upper Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Solo Woman Trip To Cairo, Hurghada, and Upper Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Queen Nefertari Tour for Solo Woman --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Solo Woman Journey to Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Solo Woman Journey to Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Solo Woman Journey to Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Adventure Tour to the Holy Family in Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Trip to Masterpieces of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Trip to Masterpieces of Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Trip to Masterpieces of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Cairo, Nile Cruise & Sahara Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Cairo, Nile Cruise & Sahara Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Cairo, Nile Cruise & Sahara Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Luxury Oberoi Zahra Nile Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Luxury Oberoi Philae Nile Cruise --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Spiritual Tour to Charming of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Spiritual Tour to Charming of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Metaphysical Tour to Egypt Monuments --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Metaphysical Tour to Egypt Monuments --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Ethereal Trip To Cairo, Luxor, and Oasis --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Dahabiya Nile River Cruise From Luxor --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Dahabiya Nile River Cruise From Luxor --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Dahabiya Nile River Cruise From Luxor --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Fayoum, and Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Egypt Absolute UNESCO Tour Include Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Egypt Absolute UNESCO Tour Include Nile Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Transcendent UNESCO Egypt Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Complete UNESCO Egypt Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Alexandria, Sharm El Sheikh & Palaces Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Marsa Alam, Fayoum & Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Alexandria, Nile Cruise & Sahara Trip --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Alexandria, Nile Cruise & Sahara Trip --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Alexandria, Nile Cruise & Sahara Trip --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Family Tour Across the Essential Wonders of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Family Tour Across the Essential Wonders of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Day Magical and Fun Egypt Family Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Day Magical and Fun Egypt Family Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Family Tour Across the Corners of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Family Tour Across the Corners of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Family Tour Across the Corners of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Egypt Classic Group Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Group Trip to Egypt Wonders With A Nile Cruise --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cultural Treasures of Egypt Group Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cultural Treasures of Egypt Group Holiday --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cultural Treasures of Egypt Group Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Group Tour Across the Marvelous Land of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Group Tour Across the Marvelous Land of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Group Tour Across the Marvelous Land of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Group Tour Across the Marvels of Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Best of Egypt Group Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Best of Egypt Group Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Life-changing Group Adventure in Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Seniors Holiday Across the Lands of Pharaohs --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Grand Egyptian Museum VIP Trip --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Grand Egyptian Museum VIP Trip --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Ultra Egypt Luxury Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Ultra Egypt Luxury Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Siwa Egypt Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Siwa Egypt Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Odyssey Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Luxor, and Sharm El Sheikh Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Luxor, and Sharm El Sheikh Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Luxor, and Sharm El Sheikh Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Oasis Egypt Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Oasis Egypt Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Sharm El Sheikh & Nile Cruise Itinerary --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Sharm El Sheikh & Nile Cruise Itinerary --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Egypt Overland Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Cairo, Sharm, Alexandria & Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Cairo, Sharm, Alexandria & Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Cairo, Sharm, Alexandria & Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Sands of Pharaohs Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Sands of Pharaohs Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Sands of Pharaohs Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Cairo, Upper Egypt, Hurghada & Catherine Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Cairo, Upper Egypt, Hurghada & Catherine Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Cairo, Upper Egypt, Hurghada & Catherine Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 19 Days Overland Egypt Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 19 Days Overland Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 19 Days Overland Egypt Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Egypt Tour Between Garden of Eden --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Egypt Tour Between Garden of Eden --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Christmas Tour in Cairo & Upper Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Christmas Tour in Cairo & Upper Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada & Nile Cruise Holiday at Christmas --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada & Nile Cruise Holiday at Christmas --> in season: Spring --> is offered.
#
# ---------------------------------------------------
# Number of packages offered: 200
# ---------------------------------------------------
# Objective value: $7,950,843.00

# %%
import pulp
import pandas as pd
import locale

# Set locale for currency formatting
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')

# Load the Excel file
file_path = 'C:/Users/Mohammed/OneDrive/Desktop/use data.xlsx'
data = pd.read_excel(file_path, sheet_name='Data')

# Extract unique tour packages and seasons
tour_packages = data['Tour Name'].unique()
seasons = data['Season'].unique()

# Create integer indices for tour packages and seasons
tour_package_indices = {tour: idx for idx, tour in enumerate(tour_packages)}
season_indices = {season: idx for idx, season in enumerate(seasons)}

# Number of tour packages and seasons
n = len(tour_packages)
m = len(seasons)

# Parameters
c_i = data['Cost of Package Per Tourist'].tolist()
c_k = data['Cost per unit of resources'].unique().tolist()
p_i = data['Price'].tolist()
b_r = 10000000  # Maximum budget for resources
R_k = data['#Available Resources'].unique().tolist()
d_min = data['Minimum Demand'].tolist()
d_max = data['Maximum Demand'].tolist()

# Create a pivot table for actual demand
demand_pivot = data.pivot(index='Tour Name', columns='Season', values='Actual Demand')
d_ij = demand_pivot.fillna(0).values.tolist()  # Fill NA values with 0 for missing data

# Initialize r_ijk as a 3-dimensional list
r_ijk = [[[0 for _ in range(len(c_k))] for _ in range(m)] for _ in range(n)]

# Fill r_ijk with values from the dataframe
for row in data.itertuples():
    i = tour_package_indices[row._1]
    j = season_indices[row.Season]
    for k in range(len(c_k)):
        r_ijk[i][j][k] = row._8  # Adjust this index if necessary based on the dataframe structure

m_ij = [50] * m  # Maximum number of packages to offer per season

# Decision Variables
x = pulp.LpVariable.dicts("x", ((i, j) for i in range(n) for j in range(m)), cat='Binary')

# Objective Function
objective = pulp.lpSum(p_i[i] * d_ij[i][j] * x[i, j] for i in range(n) for j in range(m)) - \
            pulp.lpSum(c_i[i] * d_ij[i][j] * x[i, j] for i in range(n) for j in range(m)) - \
            pulp.lpSum(c_k[k] * r_ijk[i][j][k] * x[i, j] for i in range(n) for j in range(m) for k in range(len(c_k)))

# Create the problem
prob = pulp.LpProblem("TourPackageOptimization", pulp.LpMaximize)
prob += objective

# Constraints

# Budget Constraints
for i in range(n):
    for j in range(m):
        prob += pulp.lpSum(c_k[k] * r_ijk[i][j][k] * x[i, j] for k in range(len(c_k))) <= b_r

# Resource Constraints
for k in range(len(c_k)):
    for j in range(m):
        prob += pulp.lpSum(r_ijk[i][j][k] * x[i, j] for i in range(n)) <= R_k[k]

# Demand Constraints
for i in range(n):
    for j in range(m):
        prob += d_ij[i][j] * x[i, j] >= d_min[i]
        prob += d_ij[i][j] * x[i, j] <= d_max[i]

# Package Offering Constraints
for j in range(m):
    prob += pulp.lpSum(x[i, j] for i in range(n)) <= m_ij[j]

# Prevent offering packages in non-existent seasons
for i in range(n):
    for j in range(m):
        if demand_pivot.at[tour_packages[i], seasons[j]] == 0:
            prob += x[i, j] == 0

# Solve the problem
prob.solve()

# Calculate revenue, cost, and profit
total_revenue = 0
total_cost = 0
total_package_cost = 0
total_resource_cost = 0

for i in range(n):
    for j in range(m):
        if pulp.value(x[i, j]) == 1:
            total_revenue += p_i[i] * d_ij[i][j]
            total_package_cost += c_i[i] * d_ij[i][j]
            total_resource_cost += sum(c_k[k] * r_ijk[i][j][k] * d_ij[i][j] for k in range(len(c_k)))

total_cost = total_package_cost + total_resource_cost
profit = total_revenue - total_cost

# Print the results for packages that are offered (x[i, j] == 1)
offered_packages = []
for i in range(n):
    for j in range(m):
        if pulp.value(x[i, j]) == 1:
            offered_packages.append((tour_packages[i], seasons[j]))

# Print the offered packages
for package, season in offered_packages:
    print('---------------------------------------------------')
    print()
    print(f"Package: {package} --> in season: {season} --> is offered.")

# Print the number of packages offered
num_offered_packages = len(offered_packages)
print()
print('---------------------------------------------------')
print(f"Number of packages offered: {num_offered_packages}")
print('---------------------------------------------------')

# Print the objective value as currency
objective_value = int(pulp.value(prob.objective))
print(f"Objective value: {(locale.currency(objective_value, grouping=True))}")


# Analyze and print reasons for packages not offered
not_offered_packages = []
for i in range(n):
    for j in range(m):
        if pulp.value(x[i, j]) == 0:
            reasons = []
            # Budget constraint
            if sum(c_k[k] * r_ijk[i][j][k] for k in range(len(c_k))) > b_r:
                reasons.append("Exceeds budget")
            # Resource constraint
            for k in range(len(c_k)):
                if sum(r_ijk[i][j][k] for i in range(n)) > R_k[k]:
                    reasons.append("Exceeds available resources")
            # Demand constraints
            if d_ij[i][j] < d_min[i]:
                reasons.append("Below minimum demand")
            if d_ij[i][j] > d_max[i]:
                reasons.append("Above maximum demand")
            # Package offering constraint
            if sum(pulp.value(x[i_, j]) for i_ in range(n)) >= m_ij[j]:
                reasons.append("Maximum packages offered for season")
            # Non-existent seasons
            if demand_pivot.at[tour_packages[i], seasons[j]] == 0:
                reasons.append("Non-existent season")

            not_offered_packages.append((tour_packages[i], seasons[j], reasons))

# Print the reasons for packages not offered
for package, season, reasons in not_offered_packages:
    print('---------------------------------------------------')
    print()
    print(f"Package: {package} --> in season: {season} --> is NOT offered.")
    print("Reasons:")
    for reason in reasons:
        print(f"- {reason}")
# Out:
# ---------------------------------------------------
#
# Package: 5 Days Nile Cruise from Sharm El Sheikh --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Alexandria, Cairo and Nile Cruise Holidays --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Alexandria, Cairo and Nile Cruise Holidays --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Egypt Adventure Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Egypt Adventure Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Egypt Adventure Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt & Jordan Tour to Cairo, Nile Cruise & Petra Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt & Jordan Tour to Cairo, Nile Cruise & Petra Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Budget Tour to Cairo, Nile Cruise & Alexandria --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Egypt Cheap Tour to Cairo, Nile Cruise & Alexandria --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Egypt Cheap Tour to Cairo, Nile Cruise & Alexandria --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Culture Trip to Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Culture Trip to Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Culture Trip to Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Cairo and Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Recreational Trip to Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Recreational Trip to Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt in 9 Days --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Classical Tour In Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt Cultural Sightseeing in 10 Days --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt Cultural Sightseeing in 10 Days --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Pyramids & Nile Cruise Holidays by Air --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Historical Vacation in Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Historical Vacation in Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 6 Days Egypt Jewels Luxury Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Taste of Egypt in 9 Days Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Treasures of Egypt in 11 Days Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Treasures of Egypt in 11 Days Luxury Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Explore Egypt in 12 Days Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Explore Egypt in 12 Days Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Discover Ancient Egypt in 8 Days Luxury Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Discover Ancient Egypt in 8 Days Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Ultimate Egypt in 8 Days Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Egypt 11 Days Pyramids & the Nile Luxury Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Egypt Jewels 10 Days Luxury Holiday With Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Easter Cairo & Ancient Egypt Nile River Cruise --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Easter Cairo & Ancient Egypt Nile River Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Easter Cairo & Ancient Egypt Nile River Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Honeymoon Cairo & Nile Adventure Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt in 10 Days Honeymoon Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt Classic and Romantic Honeymoon Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Egypt Classic and Romantic Honeymoon Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Honeymoon Historical Holiday in Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Essential Egypt Honeymoon Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Essential Egypt Honeymoon Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Lovely Honeymoon Tour Package Across Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Lovely Honeymoon Tour Package Across Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Experience Egypt in Luxury with Sanctuary Sun Boat III Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo & Upper Egypt Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Overland Trip Package in Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Overland Trip Package in Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Trip to the Best of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Trip to the Best of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Exceptional Trip Package in Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Luxury Cairo and Dahabiya Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Luxury Cairo and Dahabiya Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Luxury Cairo and Dahabiya Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Magnificent Egypt Tour for Senior Include Abu Simbel --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Magnificent Egypt Tour for Senior Include Abu Simbel --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Magnificent Egypt Tour for Senior Include Abu Simbel --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Golden Egypt Tour for Solo Women --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Solo Woman Tour to Essential Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Solo Woman Tour to Essential Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Solo Woman Tour to Essential Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Cleopatra’s Cairo & Nile Cruise Tour for Solo Woman --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Cleopatra’s Cairo & Nile Cruise Tour for Solo Woman --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Solo Woman Trip To Cairo, Hurghada, and Upper Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Solo Woman Trip To Cairo, Hurghada, and Upper Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Solo Woman Trip To Cairo, Hurghada, and Upper Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Queen Nefertari Tour for Solo Woman --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Solo Woman Journey to Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Solo Woman Journey to Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Solo Woman Journey to Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Adventure Tour to the Holy Family in Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Trip to Masterpieces of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Trip to Masterpieces of Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Trip to Masterpieces of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Cairo, Nile Cruise & Sahara Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Cairo, Nile Cruise & Sahara Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Cairo, Nile Cruise & Sahara Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: Luxury Oberoi Zahra Nile Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: Luxury Oberoi Philae Nile Cruise --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Spiritual Tour to Charming of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Spiritual Tour to Charming of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Metaphysical Tour to Egypt Monuments --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Metaphysical Tour to Egypt Monuments --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Ethereal Trip To Cairo, Luxor, and Oasis --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Dahabiya Nile River Cruise From Luxor --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Dahabiya Nile River Cruise From Luxor --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Dahabiya Nile River Cruise From Luxor --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Fayoum, and Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Egypt Absolute UNESCO Tour Include Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Egypt Absolute UNESCO Tour Include Nile Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Transcendent UNESCO Egypt Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Complete UNESCO Egypt Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada, Sahara & Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Alexandria, Sharm El Sheikh & Palaces Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Marsa Alam, Fayoum & Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Alexandria, Nile Cruise & Sahara Trip --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Alexandria, Nile Cruise & Sahara Trip --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cairo, Alexandria, Nile Cruise & Sahara Trip --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Family Tour Across the Essential Wonders of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Family Tour Across the Essential Wonders of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Day Magical and Fun Egypt Family Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Day Magical and Fun Egypt Family Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Family Tour Across the Corners of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Family Tour Across the Corners of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Family Tour Across the Corners of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Family Best of Egypt Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Egypt Classic Group Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Group Trip to Egypt Wonders With A Nile Cruise --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Marvelous Group Tour To Egypt Treasures --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cultural Treasures of Egypt Group Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cultural Treasures of Egypt Group Holiday --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Cultural Treasures of Egypt Group Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Group Tour Across the Marvelous Land of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Group Tour Across the Marvelous Land of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 14 Days Group Tour Across the Marvelous Land of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days All In One Egypt Group Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Group Tour Across the Marvels of Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Best of Egypt Group Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Best of Egypt Group Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Life-changing Group Adventure in Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 11 Days Seniors Holiday Across the Lands of Pharaohs --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Grand Egyptian Museum VIP Trip --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: Grand Egyptian Museum VIP Trip --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Hiking Egypt Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Ultra Egypt Luxury Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Ultra Egypt Luxury Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Siwa Egypt Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Siwa Egypt Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Odyssey Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 18 Days Exploration of Egypt Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 20 Days Cairo, Alexandria, Nile Cruise & Sharm El Sheikh Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Dazzling Egypt Tour Includes A Nile Cruise --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Tour Package to Elegance of Egypt --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 21 Days Landmarks of Egypt Holiday --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Luxor, and Sharm El Sheikh Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Luxor, and Sharm El Sheikh Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 9 Days Cairo, Luxor, and Sharm El Sheikh Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Oasis Egypt Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 10 Days Oasis Egypt Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Sharm El Sheikh & Nile Cruise Itinerary --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Sharm El Sheikh & Nile Cruise Itinerary --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Egypt Overland Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Cairo, Sharm, Alexandria & Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Cairo, Sharm, Alexandria & Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 15 Days Cairo, Sharm, Alexandria & Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Sands of Pharaohs Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Sands of Pharaohs Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 16 Days Sands of Pharaohs Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Cairo, Upper Egypt, Hurghada & Catherine Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Cairo, Upper Egypt, Hurghada & Catherine Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 17 Days Cairo, Upper Egypt, Hurghada & Catherine Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 19 Days Overland Egypt Tour Package --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 19 Days Overland Egypt Tour Package --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 19 Days Overland Egypt Tour Package --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Egypt Tour Between Garden of Eden --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 13 Days Egypt Tour Between Garden of Eden --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Christmas Tour in Cairo & Upper Egypt --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 7 Days Christmas Tour in Cairo & Upper Egypt --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Spring --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Summer --> is offered.
# ---------------------------------------------------
#
# Package: 8 Days Christmas Cairo and Nile Cruise Tour --> in season: Winter --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada & Nile Cruise Holiday at Christmas --> in season: Autumn --> is offered.
# ---------------------------------------------------
#
# Package: 12 Days Cairo, Hurghada & Nile Cruise Holiday at Christmas --> in season: Spring --> is offered.
#
# ---------------------------------------------------
# Number of packages offered: 200
# ---------------------------------------------------
# Objective value: $7,950,843.00
# ---------------------------------------------------
#
# Package: Cairo Stopover Tour --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Cairo Stopover Tour --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Cairo Stopover Tour --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Cairo Stopover Tour --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour in Cairo and the Pyramids --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour in Cairo and the Pyramids --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour in Cairo and the Pyramids --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour in Cairo and the Pyramids --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Pyramids from Cairo --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Pyramids from Cairo --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Pyramids from Cairo --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Pyramids from Cairo --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip from Luxor to Cairo by Plane --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip from Luxor to Cairo by Plane --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip from Luxor to Cairo by Plane --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip from Luxor to Cairo by Plane --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Saqqara & Memphis Tour from Cairo --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Saqqara & Memphis Tour from Cairo --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Saqqara & Memphis Tour from Cairo --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Saqqara & Memphis Tour from Cairo --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Egyptian Museum & Old Cairo Tour --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Egyptian Museum & Old Cairo Tour --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Egyptian Museum & Old Cairo Tour --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Egyptian Museum & Old Cairo Tour --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor West Bank --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor West Bank --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor West Bank --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor West Bank --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half-Day Tour to the Egyptian Museum --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half-Day Tour to the Egyptian Museum --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half-Day Tour to the Egyptian Museum --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half-Day Tour to the Egyptian Museum --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half Day Pyramids Tour in Cairo --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half Day Pyramids Tour in Cairo --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half Day Pyramids Tour in Cairo --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Half Day Pyramids Tour in Cairo --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Edfu & Kom Ombo Tour from Luxor --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Edfu & Kom Ombo Tour from Luxor --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Edfu & Kom Ombo Tour from Luxor --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Edfu & Kom Ombo Tour from Luxor --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour from Cairo to Luxor By Plane --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour from Cairo to Luxor By Plane --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour from Cairo to Luxor By Plane --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Tour from Cairo to Luxor By Plane --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Alexandria from Cairo by Car --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Alexandria from Cairo by Car --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Alexandria from Cairo by Car --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Day Trip to Alexandria from Cairo by Car --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Trip to Dandara and Abydos from Luxor --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Trip to Dandara and Abydos from Luxor --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Trip to Dandara and Abydos from Luxor --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Trip to Dandara and Abydos from Luxor --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor East and West Banks --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor East and West Banks --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Tour to Luxor East and West Banks --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# ...
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Discover Scuba Diving from Safaga Port --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Above maximum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Snorkeling Trip from Safaga Port --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Snorkeling Trip from Safaga Port --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Snorkeling Trip from Safaga Port --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Snorkeling Trip from Safaga Port --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Super Safari by Quads from Safaga Port --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Super Safari by Quads from Safaga Port --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Super Safari by Quads from Safaga Port --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Super Safari by Quads from Safaga Port --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 4 Days Christmas & New Year Nile Cruise --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 4 Days Christmas & New Year Nile Cruise --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 4 Days Christmas & New Year Nile Cruise --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 4 Days Christmas & New Year Nile Cruise --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Above maximum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 15 Days Egypt at Christmas & New Year Holiday --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 15 Days Egypt at Christmas & New Year Holiday --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 15 Days Egypt at Christmas & New Year Holiday --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 15 Days Egypt at Christmas & New Year Holiday --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Special 6 Days Holiday for Xmas & New Year --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Special 6 Days Holiday for Xmas & New Year --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Special 6 Days Holiday for Xmas & New Year --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Special 6 Days Holiday for Xmas & New Year --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 6 Days Pharaohs Adventure at Christmas --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 6 Days Pharaohs Adventure at Christmas --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 6 Days Pharaohs Adventure at Christmas --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 6 Days Pharaohs Adventure at Christmas --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Essential Egypt in 13 Days Christmas & New Year Holiday --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Above maximum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Essential Egypt in 13 Days Christmas & New Year Holiday --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Essential Egypt in 13 Days Christmas & New Year Holiday --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: Essential Egypt in 13 Days Christmas & New Year Holiday --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 10 Days Exploring Egypt in Xmas & New Year Holiday --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 10 Days Exploring Egypt in Xmas & New Year Holiday --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 10 Days Exploring Egypt in Xmas & New Year Holiday --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 10 Days Exploring Egypt in Xmas & New Year Holiday --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 7 Days Ultimate Egypt Adventure in Christmas --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 7 Days Ultimate Egypt Adventure in Christmas --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 7 Days Ultimate Egypt Adventure in Christmas --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 7 Days Ultimate Egypt Adventure in Christmas --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 2 Days El Minya Tour from Cairo --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 2 Days El Minya Tour from Cairo --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 2 Days El Minya Tour from Cairo --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: 2 Days El Minya Tour from Cairo --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Above maximum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: nan --> in season: Autumn --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: nan --> in season: Spring --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Above maximum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: nan --> in season: Summer --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Below minimum demand
# - Maximum packages offered for season
# ---------------------------------------------------
#
# Package: nan --> in season: Winter --> is NOT offered.
# Reasons:
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Exceeds available resources
# - Above maximum demand
# - Maximum packages offered for season
